# %% [markdown]
# Q1: What is Estimation Statistics? Explain point estimate and interval estimate.
# Estimation Statistics involves estimating population parameters based on sample data.
#
# Point Estimate: A single value that best approximates the population parameter. For example, the sample mean is often used as a point estimate for the population mean.
#
# Interval Estimate: Provides a range within which the population parameter is likely to lie, along with a level of confidence. For example, a confidence interval for the population mean provides a range of values that is likely to contain the true population mean.

# %% [markdown]
# Q2: Write a Python function to estimate the population mean using a sample mean and standard deviation.

# %%
import numpy as np

def estimate_population_mean(sample_mean, sample_std, sample_size):
    return sample_mean

# Example usage:
sample_mean = 10
sample_std = 2
sample_size = 100
estimated_mean = estimate_population_mean(sample_mean, sample_std, sample_size)
print("Estimated population mean:", estimated_mean)
# Out:
# Estimated population mean: 10

# %% [markdown]
# Q3: What is Hypothesis testing? Why is it used? State the importance of Hypothesis testing.
# Hypothesis testing is a statistical method used to make inferences about population parameters based on sample data. It involves making a hypothesis about the population parameter and then using sample data to either accept or reject the hypothesis.
#
# It is used to:
#
# Make decisions or draw conclusions about population parameters.
# Determine whether observed differences or relationships in data are statistically significant or occurred by chance.
# Test theories and hypotheses in scientific research.
# The importance of hypothesis testing lies in its ability to provide a systematic and objective way to make inferences about populations based on sample data, thus allowing researchers to draw meaningful conclusions from their research.

# %% [markdown]
# Q5: Write a Python script to conduct a hypothesis test on the difference between two population means, given a sample from each population.

# %%
import scipy.stats as stats

def two_sample_t_test(sample1, sample2, alpha):
    t_stat, p_value = stats.ttest_ind(sample1, sample2)
    if p_value < alpha:
        print("Reject null hypothesis: There is a significant difference between the population means.")
    else:
        print("Fail to reject null hypothesis: There is no significant difference between the population means.")

# Example usage:
sample1 = [1, 2, 3, 4, 5]
sample2 = [6, 7, 8, 9, 10]
alpha = 0.05
two_sample_t_test(sample1, sample2, alpha)
# Out:
# Reject null hypothesis: There is a significant difference between the population means.

# %% [markdown]
# Q6: What is a null and alternative hypothesis? Give some examples.
# Null Hypothesis (H0): A statement of no effect or no difference. It represents the default assumption to be tested.
# Alternative Hypothesis (H1): A statement that contradicts the null hypothesis and is what the researcher is trying to provide evidence for.
# Examples:
#
# Null Hypothesis: There is no difference in the mean scores of two groups.
# Alternative Hypothesis: There is a difference in the mean scores of two groups.
# Null Hypothesis: A new drug has no effect on blood pressure.
# Alternative Hypothesis: A new drug decreases blood pressure.

# %% [markdown]
# Q7: Write down the steps involved in hypothesis testing.
# Formulate Hypotheses: Define the null and alternative hypotheses.
# Choose Significance Level: Select the desired level of significance (alpha).
# Collect Data: Collect and summarize sample data.
# Calculate Test Statistic: Compute the test statistic appropriate for the hypothesis test.
# Determine Critical Region: Determine the critical region based on the test statistic and significance level.
# Make Decision: Compare the test statistic to the critical region and make a decision to reject or fail to reject the null hypothesis.
# Draw Conclusion: Interpret the results in the context of the problem.

# %% [markdown]
# Q8: Define p-value and explain its significance in hypothesis testing.
# p-value is the probability of obtaining test results at least as extreme as the observed results, assuming that the null hypothesis is true. In hypothesis testing, the p-value is compared to the significance level (alpha) to make decisions about the null hypothesis.
#
# If the p-value is less than or equal to the significance level, the null hypothesis is rejected.
# If the p-value is greater than the significance level, the null hypothesis is not rejected.
# The significance of the p-value lies in its ability to quantify the strength of evidence against the null hypothesis. A smaller p-value indicates stronger evidence against the null hypothesis, suggesting that the observed results are unlikely to have occurred by chance.

# %% [markdown]
# Q9: Generate a Student's t-distribution plot using Python's matplotlib library, with the degrees of freedom parameter set to 10.

# %%
import numpy as np
import matplotlib.pyplot as plt

degrees_of_freedom = 10
x = np.linspace(-4, 4, 1000)
y = stats.t.pdf(x, df=degrees_of_freedom)

plt.plot(x, y)
plt.title("Student's t-distribution (df=10)")
plt.xlabel("x")
plt.ylabel("Probability Density")
plt.show()

# %% [markdown]
# Q10: Write a Python program to calculate the two-sample t-test for independent samples, given two random samples of equal size and a null hypothesis that the population means are equal.

# %%
def two_sample_t_test_equal_means(sample1, sample2, alpha):
    t_stat, p_value = stats.ttest_ind(sample1, sample2)
    if p_value < alpha:
        print("Reject null hypothesis: The population means are not equal.")
    else:
        print("Fail to reject null hypothesis: The population means are equal.")

# Example usage:
sample1 = np.random.normal(0, 1, 100)
sample2 = np.random.normal(0, 1, 100)
alpha = 0.05
two_sample_t_test_equal_means(sample1, sample2, alpha)
# Out:
# Fail to reject null hypothesis: The population means are equal.

# %% [markdown]
# Q11: What is Student’s t distribution? When to use the t-Distribution.
# Student’s t distribution is a probability distribution that arises from the estimation of the population mean from a small sample size when the population standard deviation is unknown. It is similar to the standard normal distribution but has heavier tails.
#
# Use the t-distribution when:
#
# The population standard deviation is unknown.
# The sample size is small (typically less than 30).
# The population is approximately normal or the sample size is large enough for the Central Limit Theorem to apply.

# %% [markdown]
# Q12: What is t-statistic? State the formula for t-statistic.
# t-statistic is a measure used in hypothesis testing to determine if the means of two groups are significantly different from each other.
#
# Formula:
# t = \frac{{\bar{X}_1 - \bar{X}_2}}{{\sqrt{\frac{{s_1^2}}{{n_1}} + \frac{{s_2^2}}{{n_2}}}}}
#
# Where:X1 and X2 are the sample means. s1 and s2 are the sample standard deviations.n1 and n2 are the sample sizes.

# %% [markdown]
# Q13: A coffee shop owner wants to estimate the average daily revenue for their shop. They take a random sample of 50 days and find the sample mean revenue to be $500 with a standard deviation of $50. Estimate the population mean revenue with a 95% confidence interval.
# Using the formula for confidence interval for the population mean:
#
# Confidence Interval= bar X ± Z × s/(root(n))
# Where: X is the sample mean.s is the sample standard deviation. n is the sample size. Z is the critical value for the desired confidence level.
# For a 95% confidence level, Z=1.96 (approximately).

# %%
sample_mean = 500
sample_std = 50
sample_size = 50
confidence_level = 0.95

margin_of_error = stats.norm.ppf((1 + confidence_level) / 2) * (sample_std / np.sqrt(sample_size))
lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

print("Population mean revenue estimate (95% confidence interval):", lower_bound, "-", upper_bound)
# Out:
# Population mean revenue estimate (95% confidence interval): 486.1409617565032 - 513.8590382434968

# %% [markdown]
# Q14: A researcher hypothesizes that a new drug will decrease blood pressure by 10 mmHg. They conduct a clinical trial with 100 patients and find that the sample mean decrease in blood pressure is 8 mmHg with a standard deviation of 3 mmHg. Test the hypothesis with a significance level of 0.05.
# The null and alternative hypotheses are:
#
# Null Hypothesis (H0): The new drug does not decrease blood pressure by 10 mmHg.
# Alternative Hypothesis (H1): The new drug decreases blood pressure by 10 mmHg.
# We can use a one-sample t-test to test this hypothesis.

# %%
sample_mean = 8
population_mean = 10
sample_std = 3
sample_size = 100
alpha = 0.05

t_stat = (sample_mean - population_mean) / (sample_std / np.sqrt(sample_size))
p_value = stats.t.cdf(t_stat, df=sample_size-1)

if p_value < alpha:
    print("Reject null hypothesis: The new drug decreases blood pressure by 10 mmHg.")
else:
    print("Fail to reject null hypothesis: There is not enough evidence to conclude that the new drug decreases blood pressure by 10 mmHg.")
# Out:
# Reject null hypothesis: The new drug decreases blood pressure by 10 mmHg.

# %% [markdown]
# Q15: An electronics company produces a certain type of product with a mean weight of 5 pounds and a standard deviation of 0.5 pounds. A random sample of 25 products is taken, and the sample mean weight is found to be 4.8 pounds. Test the hypothesis that the true mean weight of the products is less than 5 pounds with a significance level of 0.01.
# Null and alternative hypotheses:
#
# Null Hypothesis (H0): The true mean weight of the products is greater than or equal to 5 pounds.
# Alternative Hypothesis (H1): The true mean weight of the products is less than 5 pounds.
# We can use a one-sample t-test for this hypothesis.

# %%
sample_mean = 4.8
population_mean = 5
sample_std = 0.5
sample_size = 25
alpha = 0.01

t_stat = (sample_mean - population_mean) / (sample_std / np.sqrt(sample_size))
p_value = stats.t.cdf(t_stat, df=sample_size-1)

if p_value < alpha:
    print("Reject null hypothesis: The true mean weight of the products is less than 5 pounds.")
else:
    print("Fail to reject null hypothesis: There is not enough evidence to conclude that the true mean weight of the products is less than 5 pounds.")
# Out:
# Fail to reject null hypothesis: There is not enough evidence to conclude that the true mean weight of the products is less than 5 pounds.

# %% [markdown]
# Q16: Two groups of students are given different study materials to prepare for a test. The first group (n1 = 30) has a mean score of 80 with a standard deviation of 10, and the second group (n2 = 40) has a mean score of 75 with a standard deviation of 8. Test the hypothesis that the population means for the two groups are equal with a significance level of 0.01.
# We can use a two-sample t-test to test this hypothesis.

# %%
sample1_mean = 80
sample1_std = 10
sample1_size = 30

sample2_mean = 75
sample2_std = 8
sample2_size = 40

alpha = 0.01

t_stat, p_value = stats.ttest_ind_from_stats(sample1_mean, sample1_std, sample1_size,
                                             sample2_mean, sample2_std, sample2_size)

if p_value < alpha:
    print("Reject null hypothesis: The population means for the two groups are not equal.")
else:
    print("Fail to reject null hypothesis: There is not enough evidence to conclude that the population means for the two groups are not equal.")
# Out:
# Fail to reject null hypothesis: There is not enough evidence to conclude that the population means for the two groups are not equal.

# %% [markdown]
# Q17: A marketing company wants to estimate the average number of ads watched by viewers during a TV program. They take a random sample of 50 viewers and find that the sample mean is 4 with a standard deviation of 1.5. Estimate the population mean with a 99% confidence interval.

# %%
sample_mean = 4
sample_std = 1.5
sample_size = 50
confidence_level = 0.99

margin_of_error = stats.norm.ppf((1 + confidence_level) / 2) * (sample_std / np.sqrt(sample_size))
lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

print("Population mean estimate (99% confidence interval):", lower_bound, "-", upper_bound)
# Out:
# Population mean estimate (99% confidence interval): 3.4535840896844654 - 4.546415910315535
